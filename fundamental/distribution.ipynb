# %%
# %matplotlib inline
import os
os.chdir("..")
print(os.getcwd())
# Out:
# C:\Users\root\Desktop\practice coding\TechJam2019

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
plt.rcParams.update({'figure.figsize':(15,8), })

import config
import utils.DataMaker as dm

# %%
train_income_df, test_income_df, demographic_df, cc_df, kplus_df, train_df, test_df = dm.read_all()

# %%
age_list = train_df["age"].unique()
age_list = sorted(age_list)
ocp_cd_list = train_df["ocp_cd"].unique()
ocp_cd_list = sorted(ocp_cd_list)

# %% [markdown]
# # Distribution

# %%
# temp_df = train_df[train_df["income"] <= 80000].copy()
temp_df = train_df.copy()
temp_df["income"].hist()

# %%
train_df["income"].quantile(0.45)
# Out:
# 28000.0

# %%
for age in age_list:
    print(age)
    temp_df = train_df[train_df["age"] == age]
    print(temp_df["income"].describe())
    plt.hist(temp_df["income"], bins=1000)
    plt.show()
# Out:
# 2
# count       792.000000
# mean      23179.292929
# std       18250.419194
# min       10000.000000
# 25%       14000.000000
# 50%       19000.000000
# 75%       26000.000000
# max      381000.000000
# Name: income, dtype: float64
# 3
# count     18974.000000
# mean      38099.399178
# std       36295.389824
# min       10000.000000
# 25%       19000.000000
# 50%       27000.000000
# 75%       42000.000000
# max      500000.000000
# Name: income, dtype: float64
# 4
# count     20142.000000
# mean      47680.220435
# std       50320.268802
# min       10000.000000
# 25%       21000.000000
# 50%       32000.000000
# 75%       53000.000000
# max      500000.000000
# Name: income, dtype: float64
# 5
# count      8019.000000
# mean      64278.962464
# std       72503.375482
# min       10000.000000
# 25%       22000.000000
# 50%       37000.000000
# 75%       76000.000000
# max      500000.000000
# Name: income, dtype: float64
# 6
# count      2073.000000
# mean      87056.922335
# ...

# %%
for ocp_cd in ocp_cd_list:
    print(ocp_cd)
    temp_df = train_df[train_df["ocp_cd"] == ocp_cd]
    print(temp_df[config.target].describe())
    plt.hist(temp_df[config.target], bins=1000)
    plt.show()
# Out:
# 0.0
# count        11.000000
# mean      47272.727273
# std       61668.615858
# min       17000.000000
# 25%       20500.000000
# 50%       27000.000000
# 75%       41000.000000
# max      229000.000000
# Name: income, dtype: float64
# 1.0
# count       863.000000
# mean      37475.086906
# std       42426.505505
# min       10000.000000
# 25%       16000.000000
# 50%       27000.000000
# 75%       40500.000000
# max      445000.000000
# Name: income, dtype: float64
# 2.0
# count       431.000000
# mean      65547.563805
# std       75881.375828
# min       10000.000000
# 25%       22000.000000
# 50%       35000.000000
# 75%       71500.000000
# max      421000.000000
# Name: income, dtype: float64
# 3.0
# count     23480.000000
# mean      49481.260647
# std       54204.781559
# min       10000.000000
# 25%       21000.000000
# 50%       32000.000000
# 75%       56000.000000
# max      500000.000000
# Name: income, dtype: float64
# 4.0
# count      1778.000000
# ...

# %%
train_df
# Out:
#          income   cc_no  gender  ocp_cd  age      pos_dt  cc_txn_amt  \
# id
# 1       20000.0   98397       2     9.0    5  2018-02-17     44700.0
# 2      106000.0    9740       2     3.0    4  2018-04-14     65200.0
# 3       29000.0       3       2     1.0    3           0         0.0
# 4       61000.0   86813       2     3.0    5  2018-04-10    770000.0
# 5       18000.0       5       2     9.0    4  2018-01-27     12000.0
# 6       19000.0   91379       1     3.0    3  2018-06-30     32000.0
# 7       53000.0   74762       1     3.0    5  2018-02-27     41100.0
# 8       16000.0   38284       2     9.0    3  2018-05-10     16300.0
# 9       19000.0   59701       1     9.0    4  2018-01-28     29000.0
# 10      17000.0      10       1     3.0    3           0         0.0
# 11      28000.0   13974       1     9.0    4  2018-02-06     41600.0
# 12      31000.0   43077       2     3.0    4  2018-05-03     27000.0
# ...

# %%
plt.hist(train_df["cc_txn_cnt"], bins=10000)
plt.show()

# %%
# income
# cc_no
# gender
# ocp_cd
# age
# pos_dt
# cc_txn_amt
# cc_txn_cnt
# cc_count
# kp_txn_count
# kp_txn_amt
# kp_txn_mean
# cc_txn_mean

feature = "ocp_cd"
train_df[train_df[feature] < train_df[feature].quantile(0.9)][[config.target, feature]].plot.scatter(config.target, feature)
# train_df[[config.target, feature]].plot.scatter(config.target, feature)

# %%
train_df
# Out:
#          income   cc_no  gender  ocp_cd  age      pos_dt  cc_txn_amt  \
# id
# 1       20000.0   98397       2     9.0    5  2018-02-17     44700.0
# 2      106000.0    9740       2     3.0    4  2018-04-14     65200.0
# 3       29000.0       3       2     1.0    3           0         0.0
# 4       61000.0   86813       2     3.0    5  2018-04-10    770000.0
# 5       18000.0       5       2     9.0    4  2018-01-27     12000.0
# 6       19000.0   91379       1     3.0    3  2018-06-30     32000.0
# 7       53000.0   74762       1     3.0    5  2018-02-27     41100.0
# 8       16000.0   38284       2     9.0    3  2018-05-10     16300.0
# 9       19000.0   59701       1     9.0    4  2018-01-28     29000.0
# 10      17000.0      10       1     3.0    3           0         0.0
# 11      28000.0   13974       1     9.0    4  2018-02-06     41600.0
# 12      31000.0   43077       2     3.0    4  2018-05-03     27000.0
# ...
